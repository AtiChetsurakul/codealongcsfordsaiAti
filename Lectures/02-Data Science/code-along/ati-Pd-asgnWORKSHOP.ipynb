# %%
import pandas as pd
pd.__version__
import seaborn as sns
import numpy as np

# %% [markdown]
# #### 1. Load csv data using pd

# %%
FILE_PATH_DATASET = "/Volumes/ExternalSSDForMac/AITLecture/CSforDSAIAUG22/codealongcsfordsaiAti/Lectures/02-Data Science/code-along/ndtv_data_final.csv"

# %%
df = pd.read_csv(FILE_PATH_DATASET)

# %%
df.head()
# Out:
#    Unnamed: 0                            Name    Brand  \
# 0           0  OnePlus 7T Pro McLaren Edition  OnePlus
# 1           1                   Realme X2 Pro   Realme
# 2           2               iPhone 11 Pro Max    Apple
# 3           3                       iPhone 11    Apple
# 4           4                    LG G8X ThinQ       LG
#
#                     Model  Battery capacity (mAh)  Screen size (inches)  \
# 0  7T Pro McLaren Edition                    4085                  6.67
# 1                  X2 Pro                    4000                  6.50
# 2       iPhone 11 Pro Max                    3969                  6.50
# 3               iPhone 11                    3110                  6.10
# 4               G8X ThinQ                    4000                  6.40
#
#   Touchscreen  Resolution x  Resolution y  Processor  ...  Rear camera  \
# 0         Yes          1440          3120          8  ...         48.0
# ...

# %% [markdown]
# ### 2 EDA step

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1359 entries, 0 to 1358
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              1359 non-null   int64
#  1   Name                    1359 non-null   object
#  2   Brand                   1359 non-null   object
#  3   Model                   1359 non-null   object
#  4   Battery capacity (mAh)  1359 non-null   int64
#  5   Screen size (inches)    1359 non-null   float64
#  6   Touchscreen             1359 non-null   object
#  7   Resolution x            1359 non-null   int64
#  8   Resolution y            1359 non-null   int64
#  9   Processor               1359 non-null   int64
#  10  RAM (MB)                1359 non-null   int64
#  11  Internal storage (GB)   1359 non-null   float64
#  12  Rear camera             1359 non-null   float64
#  13  Front camera            1359 non-null   float64
# ...

# %% [markdown]
# - there are 10 column type of object to change.
# - 0 NULL/None/missing value are found.
# - Renaming for the column name is needed.

# %%
df.describe()
# Out:
#         Unnamed: 0  Battery capacity (mAh)  Screen size (inches)  \
# count  1359.000000             1359.000000           1359.000000
# mean    679.000000             2938.489330              5.291310
# std     392.453819              873.514133              0.671357
# min       0.000000             1010.000000              2.400000
# 25%     339.500000             2300.000000              5.000000
# 50%     679.000000             3000.000000              5.200000
# 75%    1018.500000             3500.000000              5.700000
# max    1358.000000             6000.000000              7.300000
#
#        Resolution x  Resolution y    Processor      RAM (MB)  \
# count   1359.000000   1359.000000  1359.000000   1359.000000
# mean     811.543046   1490.777778     5.551141   2488.777778
# std      270.707271    557.780120     2.196562   1664.440386
# min      240.000000    320.000000     1.000000     64.000000
# 25%      720.000000   1280.000000     4.000000   1000.000000
# ...

# %%
df.isna().sum()
# Out:
# Unnamed: 0                0
# Name                      0
# Brand                     0
# Model                     0
# Battery capacity (mAh)    0
# Screen size (inches)      0
# Touchscreen               0
# Resolution x              0
# Resolution y              0
# Processor                 0
# RAM (MB)                  0
# Internal storage (GB)     0
# Rear camera               0
# Front camera              0
# Operating system          0
# Wi-Fi                     0
# Bluetooth                 0
# GPS                       0
# Number of SIMs            0
# 3G                        0
# 4G/ LTE                   0
# Price                     0
# dtype: int64

# %% [markdown]
# > 2.1 Univariate analysis

# %% [markdown]
# count plot &  displot

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Name', 'Brand', 'Model', 'Battery capacity (mAh)',
#        'Screen size (inches)', 'Touchscreen', 'Resolution x', 'Resolution y',
#        'Processor', 'RAM (MB)', 'Internal storage (GB)', 'Rear camera',
#        'Front camera', 'Operating system', 'Wi-Fi', 'Bluetooth', 'GPS',
#        'Number of SIMs', '3G', '4G/ LTE', 'Price'],
#       dtype='object')

# %%
sns.displot(df['Battery capacity (mAh)'])

# %% [markdown]
# - this has good deviation

# %%
sns.displot(df['Screen size (inches)'])

# %% [markdown]
# - screen size have some potential

# %%
sns.countplot(df['Touchscreen'])
# Out:
# /Users/atichetsurakul/opt/anaconda3/envs/ai50/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Touchscreen', ylabel='count'>

# %% [markdown]
#  - not great to use

# %%
sns.displot(df['Resolution x'] * df['Resolution y'] )

# %% [markdown]
# x*y resolution might not be that useful

# %%
sns.countplot(df['Processor'])
# Out:
# /Users/atichetsurakul/opt/anaconda3/envs/ai50/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Processor', ylabel='count'>

# %% [markdown]
# - not so much difference

# %% [markdown]
# In Ram and Internal storage some **smart**phone data might be wrong

# %%
df['RAM (MB)'].min(),df['RAM (MB)'].mean()


# df['Internal storage (GB)']
# Out:
# (64, 2488.777777777778)

# %% [markdown]
# 40 folds less than mean

# %%
df['Internal storage (GB)'].min(),df['Internal storage (GB)'].mean()
# Out:
# (0.064, 30.65486387049301)

# %% [markdown]
# almost five hundred folds less than mean

# %%
idx_ram = np.where(df['RAM (MB)'] < 128)
print(idx_ram)
# Out:
# (array([443, 587]),)

# %%
idx_mem = np.where(df['Internal storage (GB)']<0.128)

# %%
idx_mem
# Out:
# (array([443]),)

# %%
print(df.iloc[433])
# Out:
# Unnamed: 0                        433
# Name                      Xolo Q1010i
# Brand                            Xolo
# Model                          Q1010i
# Battery capacity (mAh)           2250
# Screen size (inches)              5.0
# Touchscreen                       Yes
# Resolution x                      720
# Resolution y                     1280
# Processor                           4
# RAM (MB)                         1000
# Internal storage (GB)             8.0
# Rear camera                       8.0
# Front camera                      2.0
# Operating system              Android
# Wi-Fi                             Yes
# Bluetooth                         Yes
# GPS                               Yes
# Number of SIMs                      2
# 3G                                Yes
# 4G/ LTE                            No
# Price                           13606
# Name: 433, dtype: object

# %%
print(df.iloc[587])
# Out:
# Unnamed: 0                           587
# Name                      Nokia Asha 501
# Brand                              Nokia
# Model                           Asha 501
# Battery capacity (mAh)              1200
# Screen size (inches)                 3.0
# Touchscreen                          Yes
# Resolution x                         240
# Resolution y                         320
# Processor                              1
# RAM (MB)                              64
# Internal storage (GB)              0.128
# Rear camera                          3.2
# Front camera                         0.0
# Operating system                Cyanogen
# Wi-Fi                                Yes
# Bluetooth                            Yes
# GPS                                   No
# Number of SIMs                         2
# 3G                                    No
# 4G/ LTE                               No
# Price                               4999
# Name: 587, dtype: object

# %% [markdown]
# Even these three is valid it should not catagorize as smartphone

# %%
df.drop([433, 587], axis = 0, inplace=True)

# %%
sns.displot(df['RAM (MB)'])

# %% [markdown]
# - could be a nice compare paremeter || feature

# %%
sns.countplot(df['Internal storage (GB)'])
# Out:
# /Users/atichetsurakul/opt/anaconda3/envs/ai50/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Internal storage (GB)', ylabel='count'>

# %%
# camera will be using heat map
sns.countplot(df['Operating system'])
# Out:
# /Users/atichetsurakul/opt/anaconda3/envs/ai50/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Operating system', ylabel='count'>

# %% [markdown]
# - Unuseable too much android

# %%
#  '4G/ LTE' is more practical 
sns.countplot(df['4G/ LTE'])
# Out:
# /Users/atichetsurakul/opt/anaconda3/envs/ai50/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='4G/ LTE', ylabel='count'>

# %% [markdown]
# - may be we be we can look at this
#
#
# ### summarize
# - battery screen , 4G,ram , processor,storage may be useful
# - operation system might not work due to andriod have too much varient
# - touchscreen is not work as well
# - weird phone datas were removed (2 phonee)

# %% [markdown]
# ### 2.2 Multivariate analysis

# %%
# should we start with heatmap? to screen out some thing
from matplotlib import pyplot
pyplot.figure(figsize=(150, 150),dpi=200) # width and height in inches


# sns.heatmap(Feature_corr, cbar=1, square=1, annot=0, annot_kws={'size': 15}, cmap= 'coolwarm')

# %%
# sns.heatmap(df.corr(), annot=True)
sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# - most nonobject that affect price value is memory,Ram and ..
#
# - actually Resolution (x,y) is valid choice that affect price

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Name', 'Brand', 'Model', 'Battery capacity (mAh)',
#        'Screen size (inches)', 'Touchscreen', 'Resolution x', 'Resolution y',
#        'Processor', 'RAM (MB)', 'Internal storage (GB)', 'Rear camera',
#        'Front camera', 'Operating system', 'Wi-Fi', 'Bluetooth', 'GPS',
#        'Number of SIMs', '3G', '4G/ LTE', 'Price'],
#       dtype='object')

# %% [markdown]
# #### how about the discrete one?

# %%
# 4G look great
sns.boxplot(df['4G/ LTE'],df['Price'])
# Out:
# /Users/atichetsurakul/opt/anaconda3/envs/ai50/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='4G/ LTE', ylabel='Price'>

# %% [markdown]
# - the boxplot said no good here

# %% [markdown]
# ### summarize EDA
# - From heatmap memory,Ram,and resolution are promising feature
# - the median from price base in 4G is not much diference

# %% [markdown]
# ## 3. Feature Extraction / Selection
# <br>
#
# - X <- RAM, MEM,RESOLUTION
# - y <- Price
#
# - TODO
#     - MERGE the resolution from x,y
#     - partition the data

# %%
from sklearn.model_selection import train_test_split

# %%
df['mul_res'] = df['Resolution x'] * df['Resolution y']

# %% [markdown]
# - After have a new column  > perform an <font color = 'coral'><b>Extraction feature </b></font> from dataframe

# %%
X = df[['RAM (MB)','Internal storage (GB)','mul_res']]
y = df['Price']

# %%
# check the X,y array dimension /shape < source copied
assert X.shape[0] > 0
assert X.shape[1] > 0

assert y.shape[0] > 0
assert y.ndim == 1

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3,random_state=999979)

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 949 entries, 288 to 1337
# Data columns (total 3 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   RAM (MB)               949 non-null    int64
#  1   Internal storage (GB)  949 non-null    float64
#  2   mul_res                949 non-null    int64
# dtypes: float64(1), int64(2)
# memory usage: 29.7 KB

# %%
y.info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 1357 entries, 0 to 1358
# Series name: Price
# Non-Null Count  Dtype
# --------------  -----
# 1357 non-null   int64
# dtypes: int64(1)
# memory usage: 21.2 KB

# %%
X_test.describe()
# Out:
#            RAM (MB)  Internal storage (GB)       mul_res
# count    408.000000             408.000000  4.080000e+02
# mean    2382.372549              29.378706  1.274905e+06
# std     1565.142767              33.422250  8.794327e+05
# min      256.000000               0.512000  2.049600e+05
# 25%     1000.000000               8.000000  9.216000e+05
# 50%     2000.000000              16.000000  9.216000e+05
# 75%     3000.000000              32.000000  2.073600e+06
# max    12000.000000             256.000000  4.608000e+06

# %% [markdown]
# ## 4. Preprocessing

# %% [markdown]
# - we already observed that there are not any missing/None/NULL/Blank values in the data set
#     - so fill NA is able to skip
#     -the thing TODO is stdardization

# %%
from sklearn.preprocessing import StandardScaler as SC
sc = SC()

# %%
X_train = sc.fit_transform(X_train)

X_test  = sc.transform(X_test)

# %%
X_train[:5]
# Out:
# array([[ 0.85845375,  0.01929855, -0.29272901],
#        [-0.31642237, -0.39771799, -0.46842479],
#        [ 0.27101569, -0.39771799,  0.70288038],
#        [ 0.27101569,  0.01929855, -0.35129427],
#        [ 0.27101569, -0.39771799, -0.46842479]])

# %%
X_test[:5]
# Out:
# array([[ 0.27101569,  0.01929855, -0.57254081],
#        [ 0.27101569,  0.01929855, -0.27515944],
#        [-0.90386043, -0.39771799, -0.98867951],
#        [ 0.27101569, -0.39771799, -0.46842479],
#        [-0.90386043, -0.60622625, -0.98867951]])

# %% [markdown]
# ## workshop conslusion
# - Current X_train,y_train,X_test,y_test are ready to use to predict or fit a model
#     -  with 3 normalized <font color='ocean'>promising features </font>
#         - RAM
#         - Internal storage
#         - Resolution
#     -  70/30 ratio of splitting values
