# %%
# !pip list
# Out:
# Package           Version
# ----------------- -------
# asttokens         2.0.5
# backcall          0.2.0
# cycler            0.11.0
# debugpy           1.6.2
# decorator         5.1.1
# entrypoints       0.4
# executing         0.9.0
# fonttools         4.34.4
# ipykernel         6.15.1
# ipython           8.4.0
# jedi              0.18.1
# joblib            1.1.0
# jupyter-client    7.3.4
# jupyter-core      4.11.1
# kiwisolver        1.4.4
# matplotlib        3.5.2
# matplotlib-inline 0.1.3
# nest-asyncio      1.5.5
# numpy             1.23.1
# packaging         21.3
# pandas            1.4.3
# parso             0.8.3
# pexpect           4.8.0
# pickleshare       0.7.5
# Pillow            9.2.0
# pip               20.0.2
# prompt-toolkit    3.0.30
# psutil            5.9.1
# ptyprocess        0.7.0
# pure-eval         0.2.2
# Pygments          2.12.0
# pyparsing         3.0.9
# python-dateutil   2.8.2
# pytz              2022.1
# pyzmq             23.2.0
# scikit-learn      1.1.1
# ...

# %%
# !pip install pillow

# %%
from PIL import Image

# %%
img = Image.open('cat.jpg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x1024>

# %%
import numpy as np

# %%
imgnp = np.array(img)

# %%
imgnp.shape
# Out:
# (1024, 1024, 3)

# %%
Image.fromarray(imgnp[300:600,300:900,:]).show()
# Out:
# <PIL.Image.Image image mode=RGB size=600x300>

# %%
imgnp
# Out:
# array([[[145, 119,  94],
#         [145, 119,  94],
#         [145, 119,  94],
#         ...,
#         [161, 135, 110],
#         [162, 136, 111],
#         [162, 136, 111]],
#
#        [[145, 119,  94],
#         [145, 119,  94],
#         [145, 119,  94],
#         ...,
#         [161, 135, 110],
#         [162, 136, 111],
#         [162, 136, 111]],
#
#        [[146, 120,  95],
#         [145, 119,  94],
#         [145, 119,  94],
#         ...,
#         [162, 136, 111],
#         [162, 136, 111],
#         [162, 136, 111]],
#
#        ...,
#
#        [[195, 172, 141],
#         [195, 172, 141],
#         [195, 172, 141],
#         ...,
#         [193, 174, 144],
#         [193, 174, 144],
#         [193, 174, 144]],
#
#        [[195, 172, 141],
#         [195, 172, 141],
#         [195, 172, 141],
#         ...,
#         [194, 175, 145],
#         [193, 174, 144],
#         [193, 174, 144]],
#
#        [[196, 171, 141],
#         [196, 171, 141],
#         [196, 171, 141],
# ...

# %%
img_to_blackf = imgnp.copy()

# %%
img_to_red = imgnp.copy()

# %%
img_to_red[:,:,0] =255

# %%
Image.fromarray(img_to_red).show()
# Out:
# <PIL.Image.Image image mode=RGB size=1024x1024>

# %% [markdown]
# ## TASK 1 ALL white

# %%
white = imgnp.copy()[:,:,:] * 0
white[:,:,:] -=1

# %%
Image.fromarray(white).show()
# Out:
# <PIL.Image.Image image mode=RGB size=1024x1024>

# %% [markdown]
# ## TASK 2

# %%
Image.fromarray(imgnp[300:600,300:900,:]).show()
# Out:
# <PIL.Image.Image image mode=RGB size=600x300>

# %%
red_eye_cat = imgnp.copy()

# %% [markdown]
# ## TASK 3

# %%
red_eye_cat[300:600,300:900,0] = -1
red_eye_cat[300:600,300:900,1] = 0
red_eye_cat[300:600,300:900,2] = 0

# %%
Image.fromarray(red_eye_cat).show()
# Out:
# <PIL.Image.Image image mode=RGB size=1024x1024>

# %% [markdown]
# ## TASK 4 black frame

# %%
# Create a black frame

save_area = imgnp[200:700,300:1000,:]

frame_b =  np.zeros((save_area.shape))

frame_b[10:-10,10:-10,:] = 1

img_to_blackf[200:700,300:1000,:] = save_area * frame_b

# %%
Image.fromarray(img_to_blackf).show()
# Out:
# <PIL.Image.Image image mode=RGB size=1024x1024>

# %% [markdown]
# ## TASK 5 Break 10 min

# %% [markdown]
# ## TASK 6 Rotate image

# %%
rotate_img = imgnp.copy()
rotate_img.shape
# Out:
# (1024, 1024, 3)

# %%
np.transpose(rotate_img, [0,1,2]).shape
# Out:
# (1024, 1024, 3)

# %%
Image.fromarray(np.transpose(rotate_img, [1,0,2])).show()
# Out:
# <PIL.Image.Image image mode=RGB size=1024x1024>

# %% [markdown]
# ## TASk 7
